# %%
import pandas as pd

# %%
dict = {'d1':{'t1':['a','b','c'],
              't2':['a','b','c']
              },
        'd2':{'t1':['a','b','c'],
              't2':['a','b','c']
              },
        
        
        }
df = pd.DataFrame(dict)
df
# Out:
#            d1         d2
# t1  [a, b, c]  [a, b, c]
# t2  [a, b, c]  [a, b, c]

# %%
rtn = pd.read_csv('raw_data.csv')
rtn
# Out:
#         Exam    Day                Time  \
# 0   MID EXAM  Day 1  9:00 AM - 11:00 AM
# 1   MID EXAM  Day 1  9:00 AM - 11:00 AM
# 2   MID EXAM  Day 1  9:00 AM - 11:00 AM
# 3   MID EXAM  Day 1  11:30 AM - 1:30 PM
# 4   MID EXAM  Day 1  11:30 AM - 1:30 PM
# ..       ...    ...                 ...
# 60  MID EXAM  Day 7   2:00 PM - 4:00 PM
# 61  MID EXAM  Day 7   2:00 PM - 4:00 PM
# 62  MID EXAM  Day 7   2:00 PM - 4:00 PM
# 63  MID EXAM  Day 7   2:00 PM - 4:00 PM
# 64  MID EXAM  Day 7   2:00 PM - 4:00 PM
#
#                                               Courses
# 0                       ENG 101/ENG 1011 (BSCSE/BSDS)
# 1                                    CSE 308/CSE 4609
# 2                      IPE 401/ IPE 3401 (BSCSE/BSDS)
# 3                       ENG 1013/ENG 103 (BSCSE/BSDS)
# 4                               TEC 2499 (BSCSE/BSDS)
# ..                                                ...
# 60                     PHY 2105/ PHY 105 (BSCSE/BSDS)
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 rtn = rtn.groupby('Day')
#
# File d:\Anaconda\Lib\site-packages\pandas\core\groupby\groupby.py:952, in GroupBy.__getattr__(self, attr)
#     949 if attr in self.obj:
#     950     return self[attr]
# --> 952 raise AttributeError(
#     953     f"'{type(self).__name__}' object has no attribute '{attr}'"
#     954 )
#
# AttributeError: 'DataFrameGroupBy' object has no attribute 'groupby'

# %%
rtn.head()
# Out:
#         Exam    Day                Time  \
# 0   MID EXAM  Day 1  9:00 AM - 11:00 AM
# 1   MID EXAM  Day 1  9:00 AM - 11:00 AM
# 2   MID EXAM  Day 1  9:00 AM - 11:00 AM
# 3   MID EXAM  Day 1  11:30 AM - 1:30 PM
# 4   MID EXAM  Day 1  11:30 AM - 1:30 PM
# 10  MID EXAM  Day 2  9:00 AM - 11:00 AM
# 11  MID EXAM  Day 2  9:00 AM - 11:00 AM
# 12  MID EXAM  Day 2  9:00 AM - 11:00 AM
# 13  MID EXAM  Day 2  9:00 AM - 11:00 AM
# 14  MID EXAM  Day 2  11:30 AM - 1:30 PM
# 19  MID EXAM  Day 3   2:00 PM - 4:00 PM
# 20  MID EXAM  Day 3  9:00 AM - 11:00 AM
# 21  MID EXAM  Day 3  9:00 AM - 11:00 AM
# 22  MID EXAM  Day 3  11:30 AM - 1:30 PM
# 23  MID EXAM  Day 3  11:30 AM - 1:30 PM
# 28  MID EXAM  Day 4  9:00 AM - 11:00 AM
# 29  MID EXAM  Day 4  9:00 AM - 11:00 AM
# 30  MID EXAM  Day 4  11:30 AM - 1:30 PM
# 31  MID EXAM  Day 4  11:30 AM - 1:30 PM
# 32  MID EXAM  Day 4  11:30 AM - 1:30 PM
# 36  MID EXAM  Day 5  9:00 AM - 11:00 AM
# 37  MID EXAM  Day 5  9:00 AM - 11:00 AM
# ...
